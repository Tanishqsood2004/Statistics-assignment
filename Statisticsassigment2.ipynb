# %% [markdown]
# # ** BY TANISHQ SOOD**

# %% [markdown]
# # Q 1 1. Explain the properties of the F-distribution.

# %% [markdown]
# The F-distribution is a continuous probability distribution that arises frequently in the context of hypothesis testing, particularly in analysis of variance (ANOVA) and regression analysis. Here are the key properties of the F-distribution:
#
# 1. Shape of the Distribution
# The F-distribution is positively skewed, meaning it has a long tail on the right-hand side. It is never negative because it is based on squared terms (variances or squared differences).
# The shape depends on two parameters: the numerator degrees of freedom (df₁) and the denominator degrees of freedom (df₂). As the degrees of freedom increase, the distribution becomes more symmetric and approaches a normal distribution.
# 2. Degrees of Freedom (df)
# The F-distribution has two degrees of freedom:
# Numerator degrees of freedom (df₁): This is typically the degrees of freedom associated with the variance of the group or model.
# Denominator degrees of freedom (df₂): This is the degrees of freedom associated with the error or residual variance.
# 3. Mean
# The mean of the F-distribution is given by the formula:
# Mean
# =
# 𝑑
# 𝑓
# 1
# 𝑑
# 𝑓
# 1
# −
# 2
# (for df₁ > 2)
# Mean=
# df
# 1
# ​
#  −2
# df
# 1
# ​
#
# ​
#  (for df₁ > 2)
# The mean only exists if df₁ > 2. If df₁ ≤ 2, the mean is undefined.
# 4. Variance
# The variance of the F-distribution is:
# Variance
# =
# 2
# ⋅
# (
# 𝑑
# 𝑓
# 2
# )
# 2
# ⋅
# (
# 𝑑
# 𝑓
# 1
# +
# 𝑑
# 𝑓
# 1
# −
# 2
# )
# 𝑑
# 𝑓
# 1
# ⋅
# (
# 𝑑
# 𝑓
# 2
# −
# 2
# )
# 2
# ⋅
# (
# 𝑑
# 𝑓
# 2
# −
# 4
# )
# Variance=
# df
# 1
# ​
#  ⋅(df
# 2
# ​
#  −2)
# 2
#  ⋅(df
# 2
# ​
#  −4)
# 2⋅(df
# 2
# ​
#  )
# 2
#  ⋅(df
# 1
# ​
#  +df
# 1
# ​
#  −2)
# ​
#
# The variance is defined when df₂ > 4. If df₂ ≤ 4, the variance is undefined.
# 5. Skewness
# The F-distribution is skewed to the right, especially when both df₁ and df₂ are small. The skewness decreases as the degrees of freedom increase.
# 6. Range
# The F-distribution has a range of [0, ∞). It cannot take negative values because it is based on squared terms.
# 7. Application
# The F-distribution is often used in tests of equality of variances (e.g., the F-test), in ANOVA (Analysis of Variance) to compare the variances of different groups, and in regression analysis (e.g., testing the overall significance of a regression model).
# 8. Critical Values
# The critical value of the F-distribution depends on the significance level (e.g., 0.05) and the degrees of freedom for the numerator and denominator. These values can be found in F-distribution tables or computed using statistical software.
# 9. Cumulative Distribution Function (CDF)
# The CDF of the F-distribution is used to determine the probability that an F-distributed random variable is less than or equal to a particular value. It is denoted as F(x; df₁, df₂).
# 10. Key Assumptions
# The F-distribution assumes that the data follow a normal distribution (especially for ANOVA and regression analysis). Additionally, the variances of the groups or populations being compared should be approximately equal (homogeneity of variances).

# %% [markdown]
# # 2. In which types of statistical tests is the F-distribution used, and why is it appropriate for these tests?

# %% [markdown]
# The F-distribution is primarily used in statistical tests that involve comparing variances or assessing the overall significance of models, particularly when the underlying distributions are assumed to be normal. Below are the main types of statistical tests in which the F-distribution is commonly used:
#
# 1. Analysis of Variance (ANOVA)
# Purpose: ANOVA is used to compare the means of three or more groups to determine whether there are any statistically significant differences between them.
# Why the F-distribution is used: ANOVA tests the ratio of the variance between the group means to the variance within the groups (error variance). The F-statistic is calculated by dividing the between-group variance by the within-group variance. Since variances follow a chi-square distribution, the ratio of these two variances follows an F-distribution under the null hypothesis (i.e., all group means are equal).
# Test:
# 𝐹
# =
# Variance between groups
# Variance within groups
# F=
# Variance within groups
# Variance between groups
# ​
#
# Appropriateness: The F-distribution is used because it describes the ratio of two independent chi-square variables (which are involved in the variance estimates). If the null hypothesis is true, the ratio should follow an F-distribution.
# 2. Two-Way ANOVA (or Factorial ANOVA)
# Purpose: This is an extension of ANOVA that evaluates the interaction between two factors (independent variables) and their individual effects on the dependent variable.
# Why the F-distribution is used: Similar to one-way ANOVA, the F-statistic is used to test whether the means of the groups defined by the two factors differ significantly. It uses the ratio of the variance explained by the factors (main effects and interaction) to the unexplained variance (error).
# Appropriateness: The F-distribution is used to compare multiple variance estimates, testing whether the factors or interactions explain a significant portion of the variability in the data.
# 3. Regression Analysis (F-test for Overall Significance)
# Purpose: In regression analysis, the F-test is used to test the overall significance of the model, i.e., whether at least one of the predictors is significantly related to the response variable.
# Why the F-distribution is used: The F-statistic is used to test if the variance explained by the regression model is significantly greater than the variance due to random error. The F-statistic is calculated by comparing the model’s explained variance to the residual (unexplained) variance.
# Test:
# 𝐹
# =
# Explained variance (model)
# Unexplained variance (residual)
# F=
# Unexplained variance (residual)
# Explained variance (model)
# ​
#
# Appropriateness: The F-distribution is appropriate because the numerator and denominator of the F-statistic are both related to variances, and under the null hypothesis (i.e., no relationship between predictors and response), the ratio follows an F-distribution.
# 4. Comparing Variances (F-test for Equality of Variances)
# Purpose: The F-test is used to test whether two populations have the same variance. This is especially useful in situations where the assumption of equal variances is important, such as in ANOVA or certain types of regression analysis.
# Why the F-distribution is used: The F-test compares two sample variances by taking the ratio of the two. Under the null hypothesis (the variances are equal), the ratio of two independent chi-square-distributed variables follows an F-distribution.
# Test:
# 𝐹
# =
# 𝑠
# 1
# 2
# 𝑠
# 2
# 2
# F=
# s
# 2
# 2
# ​
#
# s
# 1
# 2
# ​
#
# ​
#
# where
# 𝑠
# 1
# 2
# s
# 1
# 2
# ​
#   and
# 𝑠
# 2
# 2
# s
# 2
# 2
# ​
#   are the sample variances from two different groups.
# Appropriateness: The F-distribution is used because it is the distribution of the ratio of two independent estimates of variance (from two normal populations). If the null hypothesis of equal variances is true, the ratio will follow an F-distribution.
# 5. Multivariate Analysis of Variance (MANOVA)
# Purpose: MANOVA extends ANOVA to multiple dependent variables. It tests whether the mean vectors of the groups differ significantly.
# Why the F-distribution is used: MANOVA involves the comparison of multiple group means using multivariate statistics. Like ANOVA, the F-statistic is used to test the null hypothesis that there is no difference in the means of the groups.
# Appropriateness: The F-distribution is used in MANOVA for the same reasons as in ANOVA: it provides a way to compare the variance between group means to the variance within the groups, extending this idea to multivariate data.
# 6. Generalized Linear Models (GLM) and Other Models
# Purpose: In some cases, the F-distribution can be used in hypothesis testing for generalized linear models (e.g., logistic regression or Poisson regression) when comparing nested models or evaluating the overall significance of the model.
# Why the F-distribution is used: In certain model comparisons (e.g., likelihood ratio tests), an F-statistic may be used to assess whether a more complex model significantly improves the fit compared to a simpler model.
# Appropriateness: The F-statistic can be used to compare nested models when comparing variances of model fits, as it helps test if the additional parameters improve the model significantly.

# %% [markdown]
# **Why the F-distribution is Appropriate:**
# Variance Comparison: The F-distribution is specifically designed for testing hypotheses related to variance. It is the ratio of two independent chi-squared distributions (which represent variance estimates from normal populations), making it suitable for tests involving the comparison of variances.
# Ratio of Variances: Many tests that use the F-distribution involve the ratio of variances from different sources (between groups vs. within groups, model vs. residual), and the F-distribution models this ratio under the null hypothesis.
# Asymmetry: Since variances are always non-negative and F-statistics are calculated from squared values (e.g., squared differences in means), the distribution is positively skewed and defined only for positive values, making the F-distribution the appropriate model.
# Would you like more details or examples on how the F-distribution is used in any of these tests?

# %% [markdown]
# # Q 3 3. What are the key assumptions required for conducting an F-test to compare the variances of two
# populations?

# %% [markdown]
# To conduct an F-test to compare the variances of two populations, several key assumptions must be met for the test to be valid. These assumptions ensure that the F-test produces reliable results. Here are the key assumptions:
#
# 1. Independence of the Two Samples
# The samples from the two populations being compared must be independent of each other. This means that the data points in one sample should not influence the data points in the other sample. The independence assumption is crucial for the validity of the F-test, as it ensures that the F-statistic is calculated based on unrelated samples.
# Example: In a study comparing the variances of two teaching methods, the scores from students taught by one method should not be influenced by the scores from students taught by the other method.
# 2. Normality of the Populations
# The data in each population should come from a normally distributed population. The F-test is based on the ratio of two sample variances, which themselves are derived from normally distributed data. If the underlying populations are not normal, the F-test may not be valid.
# Testing for normality: You can check for normality using methods such as:
# Graphical methods like histograms or Q-Q plots.
# Formal tests like Shapiro-Wilk, Kolmogorov-Smirnov, or Anderson-Darling tests.
# Example: In comparing the variances of two groups' scores on a test, it’s important to ensure that both groups' score distributions are roughly normal.
# 3. Homogeneity of Variances (Equal Variances)
# The F-test assumes that the variances of the two populations are approximately equal under the null hypothesis. This assumption is fundamental because the F-test specifically compares the ratio of two sample variances. The null hypothesis for the F-test is typically that the two populations have equal variances.
# If the population variances are significantly different, the results of the F-test may not be valid, and alternative tests (such as Welch’s F-test) might be more appropriate.
# Example: If comparing the variances of two sets of test scores, the F-test assumes that the variability in the scores from both groups is similar.
# 4. Sample Sizes (Optional but Helpful for Accuracy)
# While not a strict requirement, having moderate to large sample sizes helps make the F-test more reliable. Small sample sizes can lead to inaccuracies, especially if the normality assumption is not fully satisfied.
# Effect of small sample sizes: With small sample sizes, the F-distribution may not be a good approximation, leading to potential problems in hypothesis testing.
# Example: A sample size of 30 or more is generally considered a reasonable threshold for the validity of the F-test.
# 5. Ratio of the Variances (Non-Negative Values)
# The F-statistic is the ratio of the two sample variances, so both variances must be non-negative. The F-test assumes that the numerator and denominator variances are non-negative values.
# The F-statistic itself will always be a positive value or zero, so the assumption that variances are non-negative is a natural condition for using the F-distribution.
# Summary of Assumptions for an F-Test:
# Independence: The two samples must be independent of each other.
# Normality: The data in each group must come from a normal distribution.
# Equal Variances: The variances of the two populations should be approximately equal (null hypothesis of the F-test).
# Non-Negative Values: Variances must be non-negative.
# Sample Sizes: Larger sample sizes help improve the reliability of the test.
# What Happens If Assumptions Are Violated?
# Violation of Normality: If the normality assumption is violated, the F-test may not be valid. In this case, non-parametric tests (like the Levene's Test or Bartlett's Test) can be used to test for equality of variances, as they do not rely on the assumption of normality.
# Violation of Homogeneity of Variances: If the variances are significantly unequal, the F-test might give misleading results. In such cases, a Welch's t-test (for comparing means) or other adjusted methods can be considered, though these are not designed specifically for variance comparison.

# %% [markdown]
# # Q 4 4. What is the purpose of ANOVA, and how does it differ from a t-test?

# %% [markdown]
# Purpose of ANOVA (Analysis of Variance)
# ANOVA is a statistical technique used to compare the means of three or more groups to determine if there is a significant difference among them. It helps assess whether at least one of the group means differs significantly from the others, based on the variability within and between the groups.
#
# Key Purposes of ANOVA:
# Test for Overall Group Differences: ANOVA is used when we have multiple groups (e.g., treatments, conditions, or categories) and want to test if there is any significant difference in their means.
# Assess Variance Between Groups: Instead of directly comparing the means, ANOVA compares the variance within each group and the variance between the groups. If the variance between groups is much larger than the variance within groups, it suggests that at least one of the group means is different.
# Avoid Multiple Comparisons: Rather than performing multiple pairwise t-tests, which increase the chance of a Type I error (false positive), ANOVA provides a single test that can handle multiple comparisons at once.
# Basic Steps in ANOVA:
# Null Hypothesis (H₀): All group means are equal (no significant difference between groups).
# Alternative Hypothesis (H₁): At least one group mean is different.
# Test Statistic (F-statistic): The ratio of the variance between groups to the variance within groups. A large F-statistic suggests that the group means are not all equal.
# The formula for the F-statistic in a one-way ANOVA is:
#
# 𝐹
# =
# Variance between groups
# Variance within groups
# F=
# Variance within groups
# Variance between groups
# ​
#
# If the F-statistic is large, it suggests that the means are significantly different, and you can reject the null hypothesis.
# Key Assumptions for ANOVA:
# Independence of observations
# Normality of the data in each group
# Homogeneity of variances (equal variances across groups)

# %% [markdown]
# **How ANOVA Differs from a t-test:
# While both ANOVA and the t-test are used for hypothesis testing related to group means, there are important differences between the two methods:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When to Use ANOVA vs. a t-test:
# Use ANOVA when you have three or more groups and you want to test if there is a significant difference between any of the group means.
# Use a t-test when you have only two groups and want to test if there is a significant difference in their means.

# %% [markdown]
# # Q 5 5. Explain when and why you would use a one-way ANOVA instead of multiple t-tests when comparing more
# than two groups.

# %% [markdown]
# When comparing more than two groups, it's generally better to use one-way ANOVA instead of performing multiple t-tests. Here’s why:
#
#
#
# 1. Risk of Type I Error (False Positive)
# Multiple t-tests: If you conduct multiple t-tests (e.g., comparing Group 1 vs. Group 2, Group 1 vs. Group 3, and Group 2 vs. Group 3), each t-test carries a certain probability of making a Type I error (rejecting a true null hypothesis). When you perform multiple tests, the overall risk of making at least one Type I error increases.
#
# Example: Suppose you perform 3 t-tests at a significance level of
# 𝛼
# =
# 0.05
# α=0.05. The probability of making at least one Type I error across all tests (called the family-wise error rate) is:
# 1
# −
# (
# 1
# −
# 0.05
# )
# 3
# =
# 0.14
# 1−(1−0.05)
# 3
#  =0.14
# So, there’s a 14% chance of making at least one false positive.
# One-way ANOVA: In contrast, one-way ANOVA is designed to control the overall Type I error rate for all group comparisons. When you use ANOVA, you are testing all group means simultaneously, without increasing the chance of a false positive across multiple comparisons. This makes it a more reliable and efficient approach.
#
# Why: ANOVA tests the null hypothesis that all group means are equal in one single test, and the F-distribution controls for the overall Type I error across all comparisons.
# 2. Efficiency in Handling Multiple Comparisons
# One-way ANOVA: ANOVA handles the comparison of three or more groups in one single test, which makes it more efficient and powerful. By comparing the variance between groups relative to the variance within groups, ANOVA can tell you if there are any significant differences in means across all groups, without needing to perform a separate test for each pair of groups.
#
# Example: If you’re comparing three teaching methods (A, B, and C), ANOVA will test the null hypothesis that the mean performance for all three methods is the same. You don’t need to run three separate t-tests (A vs. B, A vs. C, B vs. C) to get the same answer.
# Multiple t-tests: If you perform multiple t-tests, you will need to adjust your significance threshold (using methods like Bonferroni correction) to account for the increased risk of Type I error. This correction reduces the significance level for each individual test, which makes it harder to detect true differences.
#
# 3. Control Over the Family-Wise Error Rate (FWER)
# Multiple t-tests: When you perform multiple t-tests, the risk of committing a Type I error across all comparisons (the family-wise error rate) increases unless you correct for it. Using corrections like the Bonferroni or Holm-Bonferroni method can help, but these adjustments are conservative and may reduce statistical power (the ability to detect true effects).
#
# One-way ANOVA: With ANOVA, you maintain control over the family-wise error rate because the test only evaluates a single hypothesis. Even if ANOVA shows a significant result, if you want to identify which groups differ from each other, you can follow up with post-hoc tests (e.g., Tukey's HSD or Scheffé's test). These post-hoc tests are designed to compare pairs of means while controlling the overall Type I error.
#
# 4. Test Statistic Used
# One-way ANOVA: The F-statistic used in ANOVA compares the variance between groups to the variance within groups. A large F-statistic suggests that the between-group variance is larger than the within-group variance, which indicates a significant difference in group means. ANOVA is built for the purpose of comparing multiple groups simultaneously, and the F-statistic is specifically designed to test for differences between more than two groups.
#
# Multiple t-tests: A t-test, on the other hand, compares the difference between two means relative to the standard error. It is less efficient when comparing more than two groups because it only handles two means at a time, and it does not account for the overall variability across all groups.
#
# 5. Post-Hoc Comparisons After ANOVA
# If the result of ANOVA is significant (i.e., you reject the null hypothesis that all means are equal), post-hoc tests can be performed to determine which specific pairs of groups differ from each other. Common post-hoc tests include:
#
# Tukey's Honestly Significant Difference (HSD) test
# Bonferroni correction
# Scheffé’s test
# Dunnett's test
# These post-hoc tests are designed to control for Type I error when making multiple comparisons after a significant ANOVA result. This is a major advantage over multiple t-tests, which do not adjust for the number of comparisons unless explicitly corrected.
#
# Summary of Reasons to Use One-Way ANOVA Over Multiple t-tests:
# Reduces the Risk of Type I Error: ANOVA controls the overall Type I error rate, whereas multiple t-tests increase the risk of Type I errors unless adjustments are made.
# Efficiency: ANOVA is more efficient because it compares all groups at once, rather than requiring multiple pairwise comparisons.
# Post-hoc Testing: After a significant ANOVA, post-hoc tests can be used to determine where the differences lie between groups, with appropriate error rate control.
# Test Statistic: The F-statistic in ANOVA is designed to compare multiple groups simultaneously, whereas t-tests are designed for pairwise comparisons.
# Handling of Variance: ANOVA considers both between-group and within-group variance, while t-tests focus only on comparing the means of two groups.
# Example Situation:
# Multiple t-tests: You have three different diet plans (A, B, and C) and want to compare their effects on weight loss. If you use t-tests, you would compare A vs. B, A vs. C, and B vs. C separately, increasing the risk of Type I errors.
# One-way ANOVA: Instead, you would use one-way ANOVA to compare the three diet plans at once, which provides a single test of whether at least one of the diet plans leads to a different amount of weight loss. If ANOVA shows a significant result, you would then use a post-hoc test (e.g., Tukey’s HSD) to find out which specific diet plans differ.

# %% [markdown]
# # 6. Explain how variance is partitioned in ANOVA into between-group variance and within-group variance.
# How does this partitioning contribute to the calculation of the F-statistic

# %% [markdown]
# Variance Partitioning in ANOVA
# In Analysis of Variance (ANOVA), the total variance in the data is partitioned into two components:
#
# Between-group variance (also called explained variance or treatment variance)
# Within-group variance (also called error variance or residual variance)
# These two sources of variance are used to assess whether the group means are significantly different from each other.
#
# 1. Total Variance (Total Sum of Squares)
# The total variance measures the overall variability in the data. It is calculated by considering the squared deviations of each individual observation from the grand mean (the mean of all observations, regardless of group).
#
# Total Sum of Squares
# (
# SST
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ‾
# grand
# )
# 2
# Total Sum of Squares(SST)=
# i=1
# ∑
# N
# ​
#  (Y
# i
# ​
#  −
# Y
#
# grand
# ​
#  )
# 2
#
# Where:
#
# 𝑌
# 𝑖
# Y
# i
# ​
#   is each individual observation.
# 𝑌
# ‾
# grand
# Y
#
# grand
# ​
#   is the grand mean, i.e., the mean of all observations across all groups.
# 𝑁
# N is the total number of observations.
# 2. Between-Group Variance (Between-Group Sum of Squares)
# The between-group variance measures how much the group means differ from the grand mean. It quantifies the variation that is explained by the different treatments (or conditions) in the study.
#
# The between-group sum of squares is calculated by considering the deviations of each group mean from the grand mean, weighted by the number of observations in each group.
#
# Between-Group Sum of Squares
# (
# SSB
# )
# =
# ∑
# 𝑘
# =
# 1
# 𝐾
# 𝑛
# 𝑘
# (
# 𝑌
# ‾
# 𝑘
# −
# 𝑌
# ‾
# grand
# )
# 2
# Between-Group Sum of Squares(SSB)=
# k=1
# ∑
# K
# ​
#  n
# k
# ​
#  (
# Y
#
# k
# ​
#  −
# Y
#
# grand
# ​
#  )
# 2
#
# Where:
#
# 𝐾
# K is the number of groups.
# 𝑛
# 𝑘
# n
# k
# ​
#   is the number of observations in group
# 𝑘
# k.
# 𝑌
# ‾
# 𝑘
# Y
#
# k
# ​
#   is the mean of group
# 𝑘
# k.
# 𝑌
# ‾
# grand
# Y
#
# grand
# ​
#   is the grand mean.
# 3. Within-Group Variance (Within-Group Sum of Squares)
# The within-group variance measures how much variability exists within each group around its own mean. This captures the random error or individual differences within the groups.
#
# The within-group sum of squares is calculated by considering the deviations of each individual observation from its group mean.
#
# Within-Group Sum of Squares
# (
# SSW
# )
# =
# ∑
# 𝑘
# =
# 1
# 𝐾
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑘
# (
# 𝑌
# 𝑖
# 𝑘
# −
# 𝑌
# ‾
# 𝑘
# )
# 2
# Within-Group Sum of Squares(SSW)=
# k=1
# ∑
# K
# ​
#
# i=1
# ∑
# n
# k
# ​
#
# ​
#  (Y
# ik
# ​
#  −
# Y
#
# k
# ​
#  )
# 2
#
# Where:
#
# 𝑌
# 𝑖
# 𝑘
# Y
# ik
# ​
#   is the
# 𝑖
# i-th observation in group
# 𝑘
# k.
# 𝑌
# ‾
# 𝑘
# Y
#
# k
# ​
#   is the mean of group
# 𝑘
# k.
# 𝑛
# 𝑘
# n
# k
# ​
#   is the number of observations in group
# 𝑘
# k.
# 4. Relationship Between the Components
# The total sum of squares is the sum of the between-group sum of squares and the within-group sum of squares:
#
# SST
# =
# SSB
# +
# SSW
# SST=SSB+SSW
# This relationship reflects the fact that the total variability in the data can be partitioned into two parts:
#
# Between-group variability (SSB), which is due to differences in the group means (i.e., the effect of the treatments).
# Within-group variability (SSW), which is due to random error or individual differences within each group.
# How This Partitioning Contributes to the F-statistic Calculation
# The F-statistic in ANOVA is a ratio of the variance between groups to the variance within groups. The F-statistic helps determine if the variability between groups is greater than the variability within groups, which would indicate that at least one group mean is significantly different from the others.
#
# Formula for the F-statistic:
# 𝐹
# =
# Mean Square Between Groups (MSB)
# Mean Square Within Groups (MSW)
# F=
# Mean Square Within Groups (MSW)
# Mean Square Between Groups (MSB)
# ​
#
# Where:
#
# Mean Square Between Groups (MSB) =
# SSB
# df
# between
# df
# between
# ​
#
# SSB
# ​
#
# Mean Square Within Groups (MSW) =
# SSW
# df
# within
# df
# within
# ​
#
# SSW
# ​
#
# Degrees of Freedom:
# df_between (degrees of freedom for between groups) =
# 𝐾
# −
# 1
# K−1, where
# 𝐾
# K is the number of groups.
# df_within (degrees of freedom for within groups) =
# 𝑁
# −
# 𝐾
# N−K, where
# 𝑁
# N is the total number of observations and
# 𝐾
# K is the number of groups.
# Thus, the F-statistic can be expressed as:
#
# 𝐹
# =
# SSB
# 𝐾
# −
# 1
# SSW
# 𝑁
# −
# 𝐾
# F=
# N−K
# SSW
# ​
#
# K−1
# SSB
# ​
#
# ​
#
# Interpreting the F-statistic:
# If the F-statistic is large, it suggests that the variability between the groups is much larger than the variability within the groups, indicating that at least one group mean is significantly different from the others. In this case, you can reject the null hypothesis that all group means are equal.
# If the F-statistic is small, it suggests that the between-group variability is similar to the within-group variability, indicating that there is no significant difference between the group means. In this case, you fail to reject the null hypothesis.

# %% [markdown]
# Example to Illustrate the Partitioning of Variance:
# Suppose you are comparing the effectiveness of three teaching methods on student performance. You have data from three groups, each using a different teaching method:
#
# Group 1: Mean score = 80
# Group 2: Mean score = 85
# Group 3: Mean score = 75
# You want to determine if the differences in means are significant.
#
# The total variance (SST) will be the sum of squared deviations of each individual score from the overall mean.
# The between-group variance (SSB) will reflect the deviations of the group means from the overall mean.
# The within-group variance (SSW) will reflect how much individual scores deviate from their respective group means.
# The F-statistic will then compare these two variances to determine if the group means differ significantly.
#
# Summary:
# Total variance (SST) represents the overall variability in the data.
# Between-group variance (SSB) reflects the variation due to the different treatments or group differences.
# Within-group variance (SSW) reflects random variation or error within each group.
# The F-statistic is the ratio of the mean square between groups to the mean square within groups, and a large F-statistic indicates that the group means are significantly different.

# %% [markdown]
# # Q 7. Compare the classical (frequentist) approach to ANOVA with the Bayesian approach. What are the key
# differences in terms of how they handle uncertainty, parameter estimation, and hypothesis testing?

# %% [markdown]
# The classical (frequentist) approach to ANOVA and the Bayesian approach differ significantly in their treatment of uncertainty, parameter estimation, and hypothesis testing. Below, we'll explore the key differences between these two approaches:
#
# 1. Handling Uncertainty
# Frequentist Approach:
# Uncertainty about Parameters: In the frequentist approach, parameters (such as the group means in ANOVA) are treated as fixed but unknown values. The uncertainty about these parameters is reflected through the sampling distribution, i.e., the distribution of an estimator (such as the sample mean) across repeated samples from the population.
# Confidence Intervals: Frequentist methods report confidence intervals (CIs), which provide a range of plausible values for a parameter based on the data. The interpretation of a 95% confidence interval is that if we repeated the experiment many times, 95% of the calculated intervals would contain the true parameter value.
# Bayesian Approach:
# Uncertainty about Parameters: In the Bayesian approach, parameters are treated as random variables that have a probability distribution, reflecting the uncertainty about their true values. This is because, in Bayesian statistics, we update our beliefs about the parameters as we gather more data.
#
# Prior Distributions: Bayesian methods incorporate prior distributions to express what is known about a parameter before observing the data. These priors are updated with the observed data to produce posterior distributions, which describe the updated beliefs about the parameters.
#
# Prior: A probability distribution that reflects our beliefs about a parameter before any data is collected.
# Posterior: The updated probability distribution after the data is incorporated.
# In Bayesian ANOVA, the parameters (such as group means and variances) are assigned priors and are treated probabilistically.
#
# 2. Parameter Estimation
# Frequentist Approach:
# Point Estimates: Frequentist methods focus on point estimates of the parameters, such as the sample mean. For example, in ANOVA, the group means are estimated by the sample means.
# Maximum Likelihood Estimation (MLE): Frequentist parameter estimates are typically derived using maximum likelihood estimation, where the values of the parameters are chosen to maximize the likelihood of the observed data given those parameters.
# No Direct Probability for Parameters: In the frequentist view, parameters are fixed values. Therefore, you don’t assign probabilities to them. Instead, the probability is applied to the data, given the fixed parameter.
# Bayesian Approach:
# Posterior Distributions: In Bayesian statistics, parameter estimation results in a posterior distribution that represents the probability of the parameter values given the data. For example, rather than estimating the mean of each group with a single value, Bayesian ANOVA gives a distribution of possible means, which reflects the uncertainty about the true means.
# Sampling from the Posterior: Parameters are estimated by sampling from the posterior distribution (often using methods like Markov Chain Monte Carlo (MCMC)). This gives a range of possible values for each parameter, along with associated probabilities.
# Credible Intervals: In place of confidence intervals, Bayesian methods provide credible intervals, which are intervals where the true parameter value has a certain probability of lying, given the data and the prior. For example, a 95% credible interval means that there is a 95% probability that the true parameter value lies within that interval, based on the observed data and prior beliefs.
# 3. Hypothesis Testing
# Frequentist Approach:
# Null Hypothesis Significance Testing (NHST): In the frequentist framework, hypothesis testing is based on null hypothesis significance testing (NHST). The null hypothesis (e.g., "there is no difference between group means") is tested against an alternative hypothesis (e.g., "at least one group mean differs").
#
# F-test in ANOVA: The most common test in ANOVA is the F-test, which compares the variance between groups to the variance within groups. If the p-value is below a significance level (typically 0.05), the null hypothesis is rejected, suggesting that there is a significant difference between the group means.
# P-values: Frequentist hypothesis testing typically uses p-values to determine whether the null hypothesis can be rejected. A p-value represents the probability of observing the data (or more extreme data) under the assumption that the null hypothesis is true. A small p-value (less than the chosen significance level, e.g., 0.05) suggests that the null hypothesis is unlikely, and we reject it.
#
# Bayesian Approach:
# Posterior Probability: In Bayesian hypothesis testing, the probability of the hypothesis is updated given the data. Instead of testing a null hypothesis against an alternative hypothesis, Bayesian methods focus on the posterior probability of the hypotheses.
#
# Bayes Factor: One common approach for hypothesis testing in the Bayesian framework is the Bayes Factor, which compares the relative evidence in favor of two hypotheses (often the null vs. an alternative). The Bayes Factor is the ratio of the likelihoods of the data under the two competing hypotheses.
#
# Direct Probability Statements: Instead of p-values, Bayesian methods allow you to make direct probabilistic statements about the hypothesis. For example, after observing the data, you might say "There is a 95% probability that group A is greater than group B."
#
# No p-value: Bayesian methods do not rely on p-values, and instead, hypothesis testing is based on how well the data support the competing hypotheses in light of the priors and the data.
#
# 4. Model Comparison
# Frequentist Approach:
# ANOVA Model Comparison: In the frequentist approach, the F-statistic is used to compare models (e.g., comparing the means of different groups). The test compares the ratio of between-group variance to within-group variance to determine whether there are significant differences between the groups.
# Bayesian Approach:
# Model Comparison: Bayesian methods often use Bayes factors or posterior predictive checks to compare models. The Bayes factor compares the likelihood of the observed data under different models, helping to determine which model (or hypothesis) better explains the data.
#
# For example, in ANOVA, you might compare models where each group mean is assumed to be equal vs. models where the group means are different, using Bayes factors to assess the strength of evidence for each model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Q 8. Question: You have two sets of data representing the incomes of two different professions1
# V Profession A: [48, 52, 55, 60, 62'
# V Profession B: [45, 50, 55, 52, 47] Perform an F-test to determine if the variances of the two professions'
# incomes are equal. What are your conclusions based on the F-test?
#
# Task: Use Python to calculate the F-statistic and p-value for the given data.
#
# Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison

# %% [markdown]
# To perform an F-test to determine whether the variances of two sets of data (representing the incomes of two professions) are equal, we need to calculate the F-statistic and the corresponding p-value. The F-test compares the ratio of the variances of the two datasets.
#
# Steps to Perform the F-test:
# Null Hypothesis (H₀): The variances of the two populations are equal.
# Alternative Hypothesis (H₁): The variances of the two populations are not equal.
# Calculate the F-statistic, which is the ratio of the larger variance to the smaller variance.
# Determine the p-value associated with the F-statistic using the F-distribution.
# Compare the p-value to a significance level (typically 0.05) to decide whether to reject the null hypothesis.
# F-statistic Formula:
# 𝐹
# =
# 𝑠
# 1
# 2
# 𝑠
# 2
# 2
# F=
# s
# 2
# 2
# ​
#
# s
# 1
# 2
# ​
#
# ​
#
# Where:
#
# 𝑠
# 1
# 2
# s
# 1
# 2
# ​
#   is the larger sample variance (the numerator).
# 𝑠
# 2
# 2
# s
# 2
# 2
# ​
#   is the smaller sample variance (the denominator).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy.stats import f

# Given data
profession_A = np.array([48, 52, 55, 60, 62])
profession_B = np.array([45, 50, 55, 52, 47])

# Step 1: Calculate the sample variances
var_A = np.var(profession_A, ddof=1)  # Sample variance of Profession A
var_B = np.var(profession_B, ddof=1)  # Sample variance of Profession B

# Step 2: Calculate the F-statistic
F_statistic = var_A / var_B if var_A > var_B else var_B / var_A

# Step 3: Degrees of freedom
df_A = len(profession_A) - 1  # Degrees of freedom for Profession A
df_B = len(profession_B) - 1  # Degrees of freedom for Profession B

# Step 4: Calculate the p-value for the F-statistic
p_value = 1 - f.cdf(F_statistic, df_A, df_B)

# Step 5: Print results
print(f"Variance of Profession A: {var_A}")
print(f"Variance of Profession B: {var_B}")
print(f"F-statistic: {F_statistic}")
print(f"p-value: {p_value}")

# Step 6: Conclusion based on the significance level (alpha = 0.05)
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")
# Out:
# Variance of Profession A: 32.8
# Variance of Profession B: 15.7
# F-statistic: 2.089171974522293
# p-value: 0.24652429950266952
# Fail to reject the null hypothesis: The variances are not significantly different.

# %% [markdown]
# Explanation:
# Variances: We calculate the sample variances of Profession A and Profession B using np.var with ddof=1 to ensure it’s a sample variance (using
# 𝑛
# −
# 1
# n−1 in the denominator).
# F-statistic: The F-statistic is the ratio of the larger variance to the smaller variance.
# Degrees of Freedom: The degrees of freedom for each group is
# 𝑛
# −
# 1
# n−1, where
# 𝑛
# n is the number of observations in each group.
# p-value: We use the cumulative distribution function (f.cdf) to calculate the p-value for the F-statistic.
# Decision: If the p-value is less than the significance level (0.05), we reject the null hypothesis, indicating that the variances are significantly different. Otherwise, we fail to reject the null hypothesis, indicating that the variances are not significantly different.

# %% [markdown]
# Conclusion:
# If the p-value is less than 0.05 (as in the example), we reject the null hypothesis and conclude that the variances of the two professions' incomes are significantly different.
# If the p-value were greater than 0.05, we would fail to reject the null hypothesis, meaning there’s insufficient evidence to say the variances are different.

# %% [markdown]
# # Q 9. Question: Conduct a one-way ANOVA to test whether there are any statistically significant differences in
# average heights between three different regions with the following data1
# V Region A: [160, 162, 165, 158, 164'
# V Region B: [172, 175, 170, 168, 174'
# V Region C: [180, 182, 179, 185, 183'
# V Task: Write Python code to perform the one-way ANOVA and interpret the results
# V Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value.

# %% [markdown]
# To perform a one-way ANOVA test in Python, you can use the scipy.stats library, specifically the f_oneway function. This test will help determine if there are any statistically significant differences in average heights between the three regions.

# %%
import scipy.stats as stats

# Heights data for each region
region_A = [160, 162, 165, 158, 164]
region_B = [172, 175, 170, 168, 174]
region_C = [180, 182, 179, 185, 183]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(region_A, region_B, region_C)

# Output results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("The p-value is less than 0.05, so we reject the null hypothesis.")
    print("There is a statistically significant difference in average heights between the regions.")
else:
    print("The p-value is greater than 0.05, so we fail to reject the null hypothesis.")
    print("There is no statistically significant difference in average heights between the regions.")
# Out:
# F-statistic: 67.87330316742101
# p-value: 2.870664187937026e-07
# The p-value is less than 0.05, so we reject the null hypothesis.
# There is a statistically significant difference in average heights between the regions.

# %% [markdown]
# Explanation:
# F-statistic: Measures the ratio of variance between the groups to the variance within the groups.
# p-value: Helps determine the significance of the results. If the p-value is less than the significance level (typically 0.05), we reject the null hypothesis.
# Interpretation:
# If the p-value is less than 0.05, it indicates that there is a statistically significant difference in average heights among the three regions.
# If the p-value is greater than 0.05, it suggests that there is no statistically significant difference between the groups.
